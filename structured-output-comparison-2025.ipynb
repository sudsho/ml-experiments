# %% [markdown]
# # structured output comparison 2025
#
# instructor + outlines + pydantic-ai on the same schema.

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')

# %% [markdown]
# note: one more pass
