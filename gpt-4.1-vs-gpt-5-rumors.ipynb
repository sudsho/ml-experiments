# %% [markdown]
# # gpt 4.1 vs gpt 5 rumors
#
# what shipped vs what leaked. 4.1 is real, 5 is still rumor as of feb 2026.

# %%
models = ['gpt-4.1', 'gpt-4.1-mini', 'gpt-5-rumored']
for m in models:
    print(m)

# %%
# pricing per 1M tokens (input)
prices = {'gpt-4.1': 2.0, 'gpt-4.1-mini': 0.15}
print(prices)

# %% [markdown]
# note: rerun ok
