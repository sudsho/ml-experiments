# %% [markdown]
# # llama 3.3 vs qwen 2.5
#
# llama 3.3 (dec 2024) vs qwen 2.5. multilingual + tool-use.

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')

# %%
from transformers import AutoTokenizer
tok = AutoTokenizer.from_pretrained('gpt2')
print(len(tok))

# %% [markdown]
# note: small fixup

# %%
import json
cfg = {'lr': 3e-4, 'wd': 0.01}
print(json.dumps(cfg))
