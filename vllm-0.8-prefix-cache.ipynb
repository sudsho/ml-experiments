# %% [markdown]
# # vllm 0.8 prefix cache
#
# automatic prefix caching across requests. big win for chat with shared system prompts.

# %%
args = {'model': 'meta-llama/Llama-4-8B', 'enable_prefix_caching': True}
print(args)

# %%
# measured speedup placeholder
base_tps = 120
cached_tps = 380
print('speedup', cached_tps / base_tps)
