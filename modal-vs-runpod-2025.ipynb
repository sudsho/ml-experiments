# %% [markdown]
# # modal vs runpod 2025
#
# cold start + per-second billing comparison for short jobs.

# %%
import time
t = time.time()
print('ok', time.time()-t)

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
print('rerun ok')

# %%
import json
cfg = {'lr': 3e-4, 'wd': 0.01}
print(json.dumps(cfg))

# %%
# quick sanity
assert 1 + 1 == 2
