# %% [markdown]
# # triton inference server walkthrough
#
# deeper dive into triton. model repository layout, dynamic batching, ensemble. extends the 2022 quickstart.

# %% [markdown]
# ## obs
# langraph state checkpoint helps a lot when an agent step throws.
