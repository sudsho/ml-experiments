# %% [markdown]
# # sglang quickstart
#
# sglang gaining traction. radix attention + tree-of-thoughts native.

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %%
import time
t = time.time()
print('ok', time.time()-t)

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))
