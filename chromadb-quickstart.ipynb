# %% [markdown]
# # chroma quickstart
#
# local vector db. no server, just a pkl folder.

# %%
import chromadb

client = chromadb.Client()
col = client.create_collection('demo')
col.add(documents=['hello', 'world'], ids=['1','2'])

# %%
# few more steps
STEPS = 200
