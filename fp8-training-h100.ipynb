# %% [markdown]
# # fp8 training h100
#
# transformer engine fp8. loss curves vs bf16.

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
from transformers import AutoTokenizer
tok = AutoTokenizer.from_pretrained('gpt2')
print(len(tok))

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')
