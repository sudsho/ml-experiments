# %% [markdown]
# # modal vs runpod vs replicate
#
# serverless gpu options. cold start, $/hr, devx. modal won for me this year for one-off finetunes.

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %% [markdown]
# ## todo
# add a ragas faithfulness check to this loop.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)
