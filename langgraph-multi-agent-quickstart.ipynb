# %% [markdown]
# # langgraph multi agent quickstart
#
# tried langgraph (released jan 2024). state graph + checkpoints feel cleaner than plain langchain agents.

# %% [markdown]
# ## fix
# was comparing chat-format vs raw on different prompts. apples to apples now.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)
