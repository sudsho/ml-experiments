# %% [markdown]
# # gemini pro api quickstart
#
# google gemini pro api. mostly to compare with openai/anthropic on the same prompts. very different output style.

# %%
import torch
torch.manual_seed(0)

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %% [markdown]
# note: follow up

# %% [markdown]
# note: small fixup
