# %% [markdown]
# # llama 4 vs deepseek v4
#
# llama 4 (apr 2025 line) vs deepseek v4 (early 2026). throughput, mmlu-pro, swe-bench-lite.

# %%
import json
results = {'llama-4': {'mmlu_pro': 0.74}, 'deepseek-v4': {'mmlu_pro': 0.79}}
print(json.dumps(results, indent=2))

# %%
for model in ['llama-4', 'deepseek-v4']:
    print(f'{model}: tps placeholder')

# %%
# tokens/sec quick check
import time
t = time.time()
print('warmup', time.time()-t)

# %%
print('rerun ok')

# %% [markdown]
# note: minor edit

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean().round(3), x.std().round(3))
