# %% [markdown]
# # pytorch 2.3 features
#
# pt 2.3 highlights. flash attention 2 in scaled_dot_product_attention. torch.compile improvements.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)

# %% [markdown]
# ## todo
# rerun on the bigger eval slice.

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %% [markdown]
# ## obs
# vllm continuous batching ~3x throughput vs hf for this model + load.

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %%
# rough budget
MAX_TOK = 512
