# %% [markdown]
# # prompt tricks: cot, few-shot, role priming
#
# running the same q against gpt-3.5 with different prompts and eyeballing the result.

# %%
import openai
# openai.api_key = os.environ['OPENAI_API_KEY']

q = 'Sara has 5 apples. She gives 2 to Tom. How many does she have?'
basic = q
cot = q + '\nLet\'s think step by step.'

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %%
# fix off-by-one in slicing
x = x[:-1]
