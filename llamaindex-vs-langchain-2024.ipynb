# %% [markdown]
# # llamaindex vs langchain in 2024
#
# rebuilt the trivial pdf qa with the 2024 versions of both. lots changed since last year.

# %% [markdown]
# ## obs
# langraph state checkpoint helps a lot when an agent step throws.

# %% [markdown]
# ## todo
# rerun on the bigger eval slice.

# %% [markdown]
# ## note
# the instruct variant follows formatting hints way better than the base.

# %% [markdown]
# ## obs
# q4_k_m ~= q5_0 in quality, q4_k_m ~30% smaller. picking q4_k_m.

# %%
# eval slice size
N = 200
