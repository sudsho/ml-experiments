# %% [markdown]
# # gguf quantization with llama.cpp
#
# llama.cpp gguf formats: q4_0, q4_k_m, q5_k_m, q8_0. quick perplexity sweep on a tiny eval set.

# %% [markdown]
# ## todo
# rerun on the bigger eval slice.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)

# %%
# scratch
x = 1

# %% [markdown]
# ## obs
# q4_k_m ~= q5_0 in quality, q4_k_m ~30% smaller. picking q4_k_m.

# %% [markdown]
# ## obs
# latency spikes on first request, warmup loop fixes it.

# %% [markdown]
# ## obs
# q4_k_m ~= q5_0 in quality, q4_k_m ~30% smaller. picking q4_k_m.
