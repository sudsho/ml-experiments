# %% [markdown]
# # prometheus metrics for ml
#
# exposing model metrics (latency, qps, error rate, gpu mem) to prometheus. grafana dashboard sketch.

# %% [markdown]
# ## fix
# temp=0 in the eval, temp=0.7 only when sampling demos.

# %% [markdown]
# ## obs
# weird: f1 dropped when batch size went up. need to look.

# %% [markdown]
# ## note
# uv pip install is genuinely 5-10x faster than pip on cold cache for this repo.
