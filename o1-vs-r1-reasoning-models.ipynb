# %% [markdown]
# # o1 vs r1 reasoning models
#
# compare openai o1 with deepseek r1. token cost vs accuracy on AIME-ish prompts.

# %%
from transformers import AutoTokenizer
tok = AutoTokenizer.from_pretrained('gpt2')
print(len(tok))

# %%
import torch
print(torch.__version__)

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')
