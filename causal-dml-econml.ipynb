# %% [markdown]
# # causal dml with econml
#
# double machine learning for treatment effect estimation. picking up where the 2022 causal-inference notebook left off.

# %%
from econml.dml import LinearDML
from sklearn.ensemble import RandomForestRegressor

# est = LinearDML(model_y=RandomForestRegressor(), model_t=RandomForestRegressor())
# est.fit(Y, T, X=X, W=W)
# print(est.effect(X))

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %% [markdown]
# note: tightened up
