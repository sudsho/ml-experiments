# %% [markdown]
# # langchain agents with tools
#
# zero-shot react agent. tools = a search + a calculator.

# %%
from langchain.agents import initialize_agent, Tool
from langchain.llms import OpenAI

llm = OpenAI(temperature=0)
# search = SerpAPIWrapper()
# tools = [Tool(name='Search', func=search.run, description='web search')]

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %%
# fix off-by-one in slicing
x = x[:-1]
