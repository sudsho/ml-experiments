# %% [markdown]
# # vllm serving llama3
#
# llama 3 dropped in april. vllm continuous batching + paged attention. throughput vs hf transformers.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)

# %%
print('rerun ok')
