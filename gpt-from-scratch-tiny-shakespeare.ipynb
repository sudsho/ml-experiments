# %% [markdown]
# # mini gpt on tiny shakespeare
#
# following the karpathy walkthrough. char-level. small model so it actually trains on cpu/single-gpu.

# %% [markdown]
# ## load data

# %%
import requests, os

# tiny shakespeare
url = 'https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt'
if not os.path.exists('input.txt'):
    with open('input.txt','w',encoding='utf-8') as f:
        f.write(requests.get(url).text)
text = open('input.txt','r',encoding='utf-8').read()
print(len(text))

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {c:i for i,c in enumerate(chars)}
itos = {i:c for i,c in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])
print(vocab_size)

# %%
# use fp16 if available
dtype = torch.float16 if torch.cuda.is_available() else torch.float32

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %%
# clear cache
import gc, torch
gc.collect()
if torch.cuda.is_available(): torch.cuda.empty_cache()

# %% [markdown]
# ## obs
# decoding loops faster than expected.

# %% [markdown]
# ## obs
# more stable with temperature=0.

# %%
# small batch
BATCH = 4

# %%
# tweak temperature
TEMPERATURE = 0.7

# %%
# log a metric
print('acc:', round(acc, 4))

# %% [markdown]
# ## obs
# more stable with temperature=0.

# %% [markdown]
# ## obs
# the 4bit version saves ~60% memory at small quality cost.

# %% [markdown]
# ## todo
# try larger context next.

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %% [markdown]
# ## note
# this crashed on cpu without `device_map='auto'`. moving on.

# %%
# top_p
TOP_P = 0.9
