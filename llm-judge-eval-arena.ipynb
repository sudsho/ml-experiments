# %% [markdown]
# # llm judge eval arena
#
# pairwise judge with bradley terry rating, holdout prompts.

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')
