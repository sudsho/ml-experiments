# %% [markdown]
# # pandas basics
#
# working through pandas docs.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'a': [1,2,3,4], 'b': [5,6,7,8]})
df.head()

# %%
df.describe()

# %% [markdown]
# ### filtering rows

# %%
df[df.a > 2]
