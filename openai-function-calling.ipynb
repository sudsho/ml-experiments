# %% [markdown]
# # openai function calling
#
# the new feature from june 2023. defining a tool schema and letting the model decide when to call it.

# %%
import openai, json

functions = [{
  'name': 'get_weather',
  'description': 'get the current weather in a location',
  'parameters': {'type':'object','properties':{'location':{'type':'string'}},'required':['location']}
}]

# %%
# eval mode
model.eval()

# %% [markdown]
# ## obs
# tokenization takes longer than the forward pass for short seqs.

# %% [markdown]
# ## obs
# tokenization takes longer than the forward pass for short seqs.
