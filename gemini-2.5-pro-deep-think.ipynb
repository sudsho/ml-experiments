# %% [markdown]
# # gemini 2.5 pro deep think
#
# gemini 2.5 pro deep think mode. parallel reasoning paths, longer think budget.

# %%
prompt = 'count r in strawberry'
think_budget = 4096
print(prompt, think_budget)

# %%
scores = {'aime': 0.61, 'gpqa': 0.84}
for k, v in scores.items():
    print(k, v)
