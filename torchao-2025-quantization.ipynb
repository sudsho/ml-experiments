# %% [markdown]
# # torchao 2025 quantization
#
# int4 weight only on llama 3, accuracy vs throughput.

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')

# %%
import torch
print(torch.__version__)
