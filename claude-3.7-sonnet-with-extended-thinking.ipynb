# %% [markdown]
# # claude 3.7 sonnet extended thinking
#
# extended thinking on claude 3.7 sonnet. budget_tokens controls reasoning depth.

# %%
params = {'model': 'claude-3-7-sonnet', 'thinking': {'type': 'enabled', 'budget_tokens': 2048}}
print(params)

# %%
tasks = ['math', 'code', 'agentic']
for t in tasks:
    print('eval', t)

# %%
import json
cfg = {'lr': 3e-4, 'wd': 0.01}
print(json.dumps(cfg))
