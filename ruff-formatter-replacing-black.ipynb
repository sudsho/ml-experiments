# %% [markdown]
# # ruff formatter replacing black
#
# ruff added a formatter in 2024. drop-in for black. one tool for lint + format means one less dep.

# %%
# eval slice size
N = 200

# %%
# scratch
x = 1

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %%
# wandb run name
run_name = 'exp-' + str(seed)

# %% [markdown]
# ## obs
# weird: f1 dropped when batch size went up. need to look.

# %% [markdown]
# ## todo
# add a ragas faithfulness check to this loop.

# %% [markdown]
# ## fix
# dspy compile was failing because i had stale cache. cleared and reran.

# %% [markdown]
# ## obs
# weird: f1 dropped when batch size went up. need to look.

# %%
# eval slice size
N = 200

# %% [markdown]
# ## obs
# langraph state checkpoint helps a lot when an agent step throws.

# %%
# rough budget
MAX_TOK = 512

# %%
# wandb run name
run_name = 'exp-' + str(seed)

# %% [markdown]
# ## obs
# latency spikes on first request, warmup loop fixes it.

# %%
# eval slice size
N = 200

# %% [markdown]
# ## todo
# rerun on the bigger eval slice.

# %% [markdown]
# ## obs
# q4_k_m ~= q5_0 in quality, q4_k_m ~30% smaller. picking q4_k_m.

# %% [markdown]
# ## fix
# dspy compile was failing because i had stale cache. cleared and reran.

# %% [markdown]
# ## todo
# add a ragas faithfulness check to this loop.

# %%
# log a metric
print('acc:', round(acc, 4))

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %%
# clear cuda mem
# torch.cuda.empty_cache()

# %% [markdown]
# ## todo
# move eval data out of the notebook into a yaml.

# %% [markdown]
# ## obs
# latency spikes on first request, warmup loop fixes it.

# %%
# eval slice size
N = 200

# %% [markdown]
# ## obs
# claude 3 sonnet > gpt-3.5 on long doc qa. opus > gpt-4 on a few of these.
