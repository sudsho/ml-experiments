# %% [markdown]
# # diffusion llms llada 2
#
# llada 2 paper, masked diffusion is catching up to AR on a few mt evals. still slow on long context.

# %%
import numpy as np
mask = np.random.binomial(1, 0.3, size=32)
print(mask.sum())

# %%
steps = [4, 8, 16, 32]
for s in steps:
    print('denoise steps', s)

# %% [markdown]
# note: cleaned cells

# %%
# quick sanity
assert 1 + 1 == 2
