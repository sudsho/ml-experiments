# %% [markdown]
# # bitsandbytes 8-bit loading
#
# load_in_8bit + load_in_4bit. memory math.

# %%
from transformers import AutoModelForCausalLM

# model = AutoModelForCausalLM.from_pretrained('facebook/opt-1.3b', load_in_8bit=True, device_map='auto')

# %%
# bump max_len
MAX_LEN = 512

# %%
print('done')

# %%
print('rerun ok')
