# %% [markdown]
# # agno vs crewai vs langgraph
#
# three flavors of agentic. minimal vs role-driven vs graph-state.

# %%
import time
t = time.time()
print('ok', time.time()-t)

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')

# %%
print('done')

# %% [markdown]
# note: minor edit
