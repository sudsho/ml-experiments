# %% [markdown]
# # sglang vs vllm 2026
#
# sglang radixattention vs vllm prefix cache. both close on shared-prefix workloads now.

# %%
engines = {'sglang': '0.4.x', 'vllm': '0.8.x'}
print(engines)

# %%
for batch in [1, 16, 64]:
    print(f'batch={batch}')

# %%
# tps numbers (toy)
tps = {'sglang': 410, 'vllm': 395}
print(tps)
