# %% [markdown]
# # vllm 0.7 features
#
# v1 engine, prefix caching, speculative decoding gates.

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
import torch
print(torch.__version__)

# %% [markdown]
# note: more probes
