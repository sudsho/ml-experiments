# %% [markdown]
# # gradio vs streamlit for llm demos
#
# spinning up a chat ui in each. who wins for quick demos?

# %%
# gradio side
import gradio as gr

def chat(msg, history):
    return f'echo: {msg}'

# demo = gr.ChatInterface(chat)
# demo.launch()

# %%
x = 0
print(x)
