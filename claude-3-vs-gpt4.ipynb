# %% [markdown]
# # claude 3 vs gpt4
#
# claude 3 (opus/sonnet/haiku) released march 2024. comparing on the same qa + summarization eval as my 2023 notebook.

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %% [markdown]
# ## note
# uv pip install is genuinely 5-10x faster than pip on cold cache for this repo.

# %% [markdown]
# ## fix
# was comparing chat-format vs raw on different prompts. apples to apples now.
