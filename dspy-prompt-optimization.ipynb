# %% [markdown]
# # dspy prompt optimization
#
# dspy is the prompt-as-program thing. signatures + a teleprompter that compiles your prompts. picked up traction this year.

# %% [markdown]
# ## note
# the instruct variant follows formatting hints way better than the base.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)

# %%
# rough budget
MAX_TOK = 512

# %% [markdown]
# ## note
# uv pip install is genuinely 5-10x faster than pip on cold cache for this repo.

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.
