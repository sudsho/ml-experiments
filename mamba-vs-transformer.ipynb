# %% [markdown]
# # mamba vs transformer
#
# ssm vs attention on a long context retrieval test.

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
import torch
print(torch.__version__)

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %% [markdown]
# note: wip
