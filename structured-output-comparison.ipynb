# %% [markdown]
# # structured output comparison
#
# instructor vs outlines vs guidance. constrained decoding vs retry-with-validation. failure modes are very different.

# %% [markdown]
# ## fix
# temp=0 in the eval, temp=0.7 only when sampling demos.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)
