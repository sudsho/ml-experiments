# %% [markdown]
# # diffusion language models
#
# llada paper, masked diffusion as decoder alt.

# %%
import time
t = time.time()
print('ok', time.time()-t)

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
print('rerun ok')

# %%
# quick sanity
assert 1 + 1 == 2

# %%
print('rerun ok')
