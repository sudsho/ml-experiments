# %% [markdown]
# # mcp servers quickstart
#
# mcp went mainstream in 2026. claude desktop, cursor, zed all speak it. tiny stdio server demo.

# %%
server_cfg = {'name': 'demo-fs', 'transport': 'stdio'}
print(server_cfg)

# %%
tools = ['list_dir', 'read_file', 'grep']
for t in tools:
    print('expose', t)

# %%
# host config snippet
import json
cfg = {'mcpServers': {'demo': {'command': 'python', 'args': ['server.py']}}}
print(json.dumps(cfg, indent=2))
