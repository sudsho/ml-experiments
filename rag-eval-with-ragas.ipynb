# %% [markdown]
# # rag eval with ragas
#
# ragas 0.1+. faithfulness, answer relevance, context precision/recall. finally a metric stack instead of vibes.

# %% [markdown]
# ## fix
# was comparing chat-format vs raw on different prompts. apples to apples now.

# %%
# log a metric
print('acc:', round(acc, 4))
