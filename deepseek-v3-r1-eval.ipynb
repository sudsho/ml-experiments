# %% [markdown]
# # deepseek v3 r1 eval
#
# deepseek r1 just dropped (jan 2025). pure rl reasoning model. testing on math + simple chains.

# %%
import torch
print(torch.__version__)

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))
