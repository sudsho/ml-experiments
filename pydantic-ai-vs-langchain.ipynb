# %% [markdown]
# # pydantic ai vs langchain
#
# type-first agents. less magic than langchain, plays nice with mypy.

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')
