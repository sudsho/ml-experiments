# %% [markdown]
# # sentence-transformers 3.0
#
# st 3.0 added native multi-gpu training + better matryoshka support.

# %% [markdown]
# ## obs
# vllm continuous batching ~3x throughput vs hf for this model + load.

# %% [markdown]
# ## fix
# temp=0 in the eval, temp=0.7 only when sampling demos.

# %% [markdown]
# ## fix
# was comparing chat-format vs raw on different prompts. apples to apples now.

# %%
# eval slice size
N = 200

# %% [markdown]
# ## fix
# dspy compile was failing because i had stale cache. cleared and reran.
