# %% [markdown]
# # uv package manager
#
# uv from astral (feb 2024). way faster than pip-tools / poetry for resolving + installing.

# %% [markdown]
# ## todo
# add a ragas faithfulness check to this loop.

# %% [markdown]
# ## fix
# temp=0 in the eval, temp=0.7 only when sampling demos.

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %% [markdown]
# ## todo
# rerun on the bigger eval slice.

# %%
# scratch
x = 1
