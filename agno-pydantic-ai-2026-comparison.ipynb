# %% [markdown]
# # agno vs pydantic ai 2026
#
# agno (formerly phidata) and pydantic-ai both stabilized. typed tools, structured exits, less retry plumbing.

# %%
frameworks = ['agno', 'pydantic-ai', 'langgraph']
for f in frameworks:
    print('compare', f)

# %%
# pydantic-ai style
from pydantic import BaseModel
class Out(BaseModel):
    answer: str
    confidence: float
print(Out.model_fields.keys())
