# %% [markdown]
# # pandas 1.0 features
#
# pandas hit 1.0 in jan 2020. trying out the new bits.

# %%
import pandas as pd
print(pd.__version__)

# %%
import numpy as np
df = pd.DataFrame({'a': [1,2,np.nan,4], 'b': ['x','y',None,'z']})
df

# %%
# new StringDtype
s = pd.Series(['a', 'b', None], dtype='string')
print(s.dtype)
print(s)
