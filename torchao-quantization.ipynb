# %% [markdown]
# # torchao quantization
#
# torchao (2024). int8 dynamic quant, weight-only int4. measuring acc drop vs latency win.

# %%
# rough budget
MAX_TOK = 512

# %%
import torch
torch.manual_seed(0)

# %% [markdown]
# ## obs
# llama 3 8b instruct + good system prompt comes surprisingly close to gpt-3.5.

# %%
# eval slice size
N = 200

# %% [markdown]
# note: tightened up
