# %% [markdown]
# # huggingface datasets
#
# playing with the datasets library. mostly to see what's available without writing my own loader for the 50th time.

# %%
from datasets import load_dataset
ds = load_dataset('imdb')
print(ds)

# %% [markdown]
# ## what's in there

# %%
print(ds['train'][0])
print('train size:', len(ds['train']))
print('test size:', len(ds['test']))

# %% [markdown]
# ## map for tokenization (preview, will use in bert notebook)

# %%
# from transformers import AutoTokenizer
# tok = AutoTokenizer.from_pretrained('bert-base-uncased')
# def tokenize(b): return tok(b['text'], truncation=True, padding='max_length', max_length=128)
# tokenized = ds.map(tokenize, batched=True)

# %%
# todo: try lr=3e-4

# %%
# todo: try lr=3e-4

# %% [markdown]
# hp tweak.

# %%
# checkpoint
# results above were the best so far
