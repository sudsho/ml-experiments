# %% [markdown]
# # mlflow llm tracking
#
# mlflow 2.4+ added prompt + llm tracking. trying it on a small prompt eval.

# %%
import mlflow

# mlflow.set_experiment('prompt-eval')
# with mlflow.start_run():
#     mlflow.log_param('prompt_template', 'translate to french: {x}')
#     mlflow.log_metric('exact_match', 0.83)

# %%
print('done')
