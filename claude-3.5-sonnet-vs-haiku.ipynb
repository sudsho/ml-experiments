# %% [markdown]
# # claude 3.5 sonnet vs haiku
#
# size vs cost tradeoff for routing tasks.

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
from transformers import AutoTokenizer
tok = AutoTokenizer.from_pretrained('gpt2')
print(len(tok))

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %% [markdown]
# note: one more pass

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')
