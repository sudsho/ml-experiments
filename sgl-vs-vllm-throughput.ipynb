# %% [markdown]
# # sgl vs vllm throughput
#
# throughput on llama 3.1 8b. batch 32, seq 1024.

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %%
import torch
print(torch.__version__)
