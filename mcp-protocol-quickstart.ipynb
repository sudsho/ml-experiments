# %% [markdown]
# # mcp protocol quickstart
#
# anthropic mcp from late 2024. servers expose tools, hosts call them. tiny demo client.

# %%
import pandas as pd
rows = [{'a': i, 'b': i*2} for i in range(5)]
df = pd.DataFrame(rows)
print(df)

# %%
for batch in [1, 8, 32]:
    print(f'batch={batch}')

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %% [markdown]
# note: tightened up

# %%
import json
cfg = {'lr': 3e-4, 'wd': 0.01}
print(json.dumps(cfg))

# %% [markdown]
# note: tightened up
