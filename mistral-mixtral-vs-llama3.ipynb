# %% [markdown]
# # mistral / mixtral vs llama3
#
# side by side: mistral 7b, mixtral 8x7b, llama 3 8b. instruct variants. small benchmark on a held-out qa set.

# %%
# clear cuda mem
# torch.cuda.empty_cache()

# %% [markdown]
# ## note
# uv pip install is genuinely 5-10x faster than pip on cold cache for this repo.

# %% [markdown]
# ## obs
# claude 3 sonnet > gpt-3.5 on long doc qa. opus > gpt-4 on a few of these.

# %%
# clear cuda mem
# torch.cuda.empty_cache()

# %%
# eval slice size
N = 200

# %% [markdown]
# ## todo
# move eval data out of the notebook into a yaml.

# %%
import torch
torch.manual_seed(0)

# %%
# eval slice size
N = 200

# %%
# rough budget
MAX_TOK = 512

# %%
# log a metric
print('acc:', round(acc, 4))

# %% [markdown]
# ## note
# the instruct variant follows formatting hints way better than the base.

# %% [markdown]
# ## obs
# weird: f1 dropped when batch size went up. need to look.

# %% [markdown]
# ## reminder
# remember to clear cuda cache between runs.

# %%
# tokenizer warmup
# tok = AutoTokenizer.from_pretrained(model_id)

# %%
# rough budget
MAX_TOK = 512

# %% [markdown]
# ## note
# the instruct variant follows formatting hints way better than the base.

# %% [markdown]
# ## obs
# q4_k_m ~= q5_0 in quality, q4_k_m ~30% smaller. picking q4_k_m.
