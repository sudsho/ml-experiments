# %% [markdown]
# # gemini 2 flash thinking
#
# google launched gemini 2 flash thinking dec 2024, doc generated content + chain of thought trace.

# %%
import time
t = time.time()
print('ok', time.time()-t)

# %%
from openai import OpenAI
client = OpenAI()
print('client ready')

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean(), x.std())

# %%
import json
cfg = {'temp': 0.7, 'top_p': 0.9}
print(json.dumps(cfg))

# %% [markdown]
# note: follow up

# %%
import numpy as np
x = np.random.randn(8, 4)
print(x.mean().round(3), x.std().round(3))

# %%
import time
t = time.time()
print('check', round(time.time()-t, 4))

# %% [markdown]
# note: tightened up
