# %% [markdown]
# # matplotlib practice
#
# learning to make plots that don't look terrible.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(x, np.sin(x), label='sin')
ax.plot(x, np.cos(x), label='cos')
ax.legend()
ax.set_title('trig')
plt.show()

# %% [markdown]
# ## subplots grid

# %%
fig, axes = plt.subplots(2, 2, figsize=(8,6))
for i, ax in enumerate(axes.flat):
    ax.plot(x, np.sin(x + i))
    ax.set_title(f'phase {i}')
plt.tight_layout()

# %% [markdown]
# ## styles

# %%
plt.style.use('seaborn')
plt.plot(x, np.sin(x))
plt.show()
plt.style.use('default')

# %%
# notes for next time:
#   - more epochs
#   - bigger batch

# %%
# saved

# %%
# todo: try lr=3e-4

# %% [markdown]
# checkpoint.
